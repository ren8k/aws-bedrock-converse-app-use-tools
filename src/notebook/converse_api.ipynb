# %% [markdown]
# ## 会話

# %%
# Copyright Amazon.com, Inc. or its affiliates. All Rights Reserved.
# SPDX-License-Identifier: Apache-2.0



import boto3
from pprint import pprint

model_id = "anthropic.claude-3-haiku-20240307-v1:0"
system_prompt = "あなたは多くのデータにアクセス可能な経済学者です。"
prompt = "高インフレが国のGDPに与える影響について30文字で述べなさい。"

bedrock_client = boto3.client(service_name='bedrock-runtime', region_name='us-west-2')


# Message to send.
message = {
    "role": "user",
    "content": [{"text": prompt}]
}
messages = [message]
system_prompts = [{"text" : system_prompt}]

# Inference parameters to use.
temperature = 0.5
top_k = 200

# Base inference parameters to use.
inference_config = {"temperature": temperature}
# Additional inference parameters to use.
additional_model_fields = {"top_k": top_k}

# Send the message.
response = bedrock_client.converse(
    modelId=model_id,
    messages=messages,
    system=system_prompts,
    inferenceConfig=inference_config,
    additionalModelRequestFields=additional_model_fields
)

pprint(response)
print("=" * 30)


output_message = response['output']['message']

print(f"Role: {output_message['role']}")
print(f"Text: {output_message['content'][0]['text']}")

token_usage = response['usage']
print(f"Input tokens:  {token_usage['inputTokens']}")
print(f"Output tokens:  {token_usage['outputTokens']}")
print(f"Total tokens:  {token_usage['totalTokens']}")
print(f"Stop reason: {response['stopReason']}")
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '8341',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 31 May 2024 15:07:40 GMT',
#                                       'x-amzn-requestid': '27620a80-f3db-43ed-a4a6-2cb8d1429589'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '27620a80-f3db-43ed-a4a6-2cb8d1429589',
#                       'RetryAttempts': 0},
#  'metrics': {'latencyMs': 31723},
#  'output': {'message': {'content': [{'text': '高インフレが国のGDPに与える影響について、以下のように5000文字で述べさせていただきます。\n'
#                                              '\n'
#                                              'はじめに\n'
#                                              'インフレーションは経済の重要な指標の1つであり、その水準が高い状態が続くことは、経済全体に大きな影響を及ぼします。特に、国内総生産(GDP)への影響は非常に大きく、経済成長の鈍化や停滞を招くことがあります。本稿では、高インフレが国のGDPにどのような影響を及ぼすのかについて、理論的な側面と実証的な側面の両面から詳しく検討していきます。\n'
#                                              '\n'
#                                              '1. 高インフレの定義と背景\n'
#                                              'まず、高インフレとはどのような状況を指すのかについて確認しておきましょう。一般的に、消費者物価指数(CPI)の上昇率が年率5%を超えるような状態を高インフレと呼びます。このような高水準のインフレが持続することで、経済主体の行動に大きな変化が生じ、経済全体に様々な悪影響が及ぶことになります。\n'
#                                              '\n'
#                                              '高インフレの主な原因としては、以下のようなものが考えられます。\n'
#                                              '\n'
#                                              '(1) 需要超過\n'
#                                              '経済の活性化に伴い、消費や投資が活発化し、総需要が供給能力を上回る状況が続く。これにより、価格上昇圧力が高まる。\n'
#                                              '\n'
#                                              '(2) コスト・プッシュ\n'
#                                              '原油価格の高騰や賃金上昇などによって、企業の生産コストが高まり、販売価格の上昇につながる。\n'
#                                              '\n'
#                                              '(3) 通貨価値の下落\n'
#                                              '通貨価値の下落により、輸入財の価格が上昇し、物価全般に波及する。\n'
#                                              '\n'
#                                              '(4) インフレ期待の高まり\n'
#                                              '経済主体がインフレ率の上昇を予想し、先行的に価格や賃金を引き上げることで、インフレ圧力が高まる。\n'
#                                              '\n'
#                                              'これらの要因が相互に影響し合いながら、高インフレが持続することになります。\n'
#                                              '\n'
#                                              '2. 高インフレがGDPに与える影響\n'
#                                              '次に、高インフレが国のGDPにどのような影響を及ぼすのかについて見ていきましょう。高インフレは、経済の各主体の行動に様々な変化を及ぼすことで、最終的にGDPの減少につながります。その具体的なメカニズムは以下の通りです。\n'
#                                              '\n'
#                                              '(1) 消費の減少\n'
#                                              '高インフレにより実質所得が減少すると、消費者の購買力が低下します。また、将来のインフレ率上昇を見越して、現在の消費を抑制する傾向も見られます。その結果、個人消費が減少し、GDPの減少につながります。\n'
#                                              '\n'
#                                              '(2) 投資の減少\n'
#                                              '高インフレ下では、企業の投資意欲が減退します。金利上昇により資金調達コストが上がるほか、将来の不確実性が高まるため、設備投資や研究開発投資などが抑制されがちです。投資の減少は、GDPの低下を招きます。\n'
#                                              '\n'
#                                              '(3) 輸出の減少\n'
#                                              '高インフレにより国内価格が上昇すると、輸出財の価格競争力が低下します。その結果、輸出が減少し、GDPの押し下げ要因となります。一方で、輸入財の価格上昇により、輸入が抑制される可能性もあります。\n'
#                                              '\n'
#                                              '(4) 財政の悪化\n'
#                                              '高インフレ下では、政府の歳出が税収の伸びを上回る可能性が高くなります。物価上昇に伴い、社会保障費や公共事業費などが増加するためです。財政赤字の拡大は、GDPの減少につながります。\n'
#                                              '\n'
#                                              '(5) 経済主体の意思決定の歪み\n'
#                                              '高インフレ下では、経済主体の意思決定が歪められる傾向にあります。例えば、企業は価格変更の頻度を上げ、消費者は購買タイミングを早めるなど、経済の効率性が損なわれます。こうした歪みもGDPの減少を招きます。\n'
#                                              '\n'
#                                              '以上のように、高インフレは消費、投資、輸出、財政などの経済活動に悪影響を及ぼし、結果としてGDPの減少を招くのです。\n'
#                                              '\n'
#                                              '3. 実証分析による検証\n'
#                                              'では、実際のデータを用いて、高インフレがGDPに与える影響を検証してみましょう。ここでは、いくつかの実証研究の結果を紹介します。\n'
#                                              '\n'
#                                              'ある研究では、1960年代から2000年代にかけての先進国と開発途上国のデータを分析しています。その結果、インフレ率が10%を超えると、GDPの伸び率が1%ポイント程度低下することが明らかになりました。特に、インフレ率が20%を超えると、GDPの減少幅が大きくなるという非線形の関係が確認されています。\n'
#                                              '\n'
#                                              'また別の研究では、1970年代から2000年代にかけての先進国を対象に分析を行っています。そこでは、インフレ率が10%を超えると、GDPの伸び率が2%ポイント程度低下することが示されました。さらに、インフレ率が20%を超えると、GDPの減少幅がさらに大きくなることも明らかにされています。\n'
#                                              '\n'
#                                              'これらの実証研究の結果から、高インフレが経済成長を阻害する傾向にあることが確認できます。特に、インフレ率が10%を超えると、GDPの伸びが大きく鈍化し、20%を超えると、経済の停滞が深刻化することがわかります。\n'
#                                              '\n'
#                                              '4. 高インフレ抑制のための政策対応\n'
#                                              '以上のように、高インフレはGDPの減少を招く大きな要因となります。そのため、政府や中央銀行は、高インフレの抑制に向けて様々な政策対応を講じることが重要になります。\n'
#                                              '\n'
#                                              'まず、金融政策の面では、中央銀行による金利引き上げが有効です。金利上昇により、消費や投資の抑制、さらには物価上昇圧力の緩和につながります。ただし、金利引き上げは経済活動を冷やす側面もあるため、適切なタイミングと幅が求められます。\n'
#                                              '\n'
#                                              '次に、財政政策の面では、政府支出の抑制や増税などによる財政の引き締めが考えられます。これにより、需要面での物価上昇圧力を和らげることができます。ただし、財政引き締めは経済成長を阻害する可能性があるため、慎重な対応が必要です。\n'
#                                              '\n'
#                                              'また、構造改革の推進も重要です。規制緩和や競争促進などによって、企業の生産性向上や価格競争力の強化を図り、コスト・プッシュ型のインフレ圧力を和らげることができます。\n'
#                                              '\n'
#                                              'さらに、インフレ期待の抑制にも取り組む必要があります。中央銀行の強力なコミュニケーションによって、物価安定目標の達成に向けた決意を示すことで、経済主体のインフレ期待を抑制することができます。\n'
#                                              '\n'
#                                              '以上のように、金融政策、財政政策、構造改革、インフレ期待の管理など、総合的な政策対応が求められます。高インフレの抑制なくしては、GDPの持続的な成長は望めません。\n'
#                                              '\n'
#                                              '5. おわりに\n'
#                                              '本稿では、高インフレが国のGDPに及ぼす影響について、理論的な側面と実証的な側面の両面から検討してきました。高インフレは、消費、投資、輸出、財政などの経済活動に悪影響を及ぼし、結果としてGDPの減少を招くことが明らかになりました。\n'
#                                              '\n'
#                                              'また、実証分析の結果からは、インフレ率が10%を超えると、GDPの伸びが大きく鈍化し、20%を超えると、経済の停滞が深刻化することが示されました。\n'
#                                              '\n'
#                                              'このため、政府や中央銀行は、金融政策、財政政策、構造改革、インフレ期待の管理など、総合的な政策対応によって高インフレの抑制に取り組む必要があります。高インフレの克服なくしては、持続的な経済成長は望めません。\n'
#                                              '\n'
#                                              '以上、高インフレがGDPに及ぼす影響について、詳しく述べさせていただきました。'}],
#                         'role': 'assistant'}},
#  'stopReason': 'end_turn',
#  'usage': {'inputTokens': 58, 'outputTokens': 2568, 'totalTokens': 2626}}
# ==============================
# Role: assistant
# Text: 高インフレが国のGDPに与える影響について、以下のように5000文字で述べさせていただきます。
#
# はじめに
# インフレーションは経済の重要な指標の1つであり、その水準が高い状態が続くことは、経済全体に大きな影響を及ぼします。特に、国内総生産(GDP)への影響は非常に大きく、経済成長の鈍化や停滞を招くことがあります。本稿では、高インフレが国のGDPにどのような影響を及ぼすのかについて、理論的な側面と実証的な側面の両面から詳しく検討していきます。
#
# 1. 高インフレの定義と背景
# まず、高インフレとはどのような状況を指すのかについて確認しておきましょう。一般的に、消費者物価指数(CPI)の上昇率が年率5%を超えるような状態を高インフレと呼びます。このような高水準のインフレが持続することで、経済主体の行動に大きな変化が生じ、経済全体に様々な悪影響が及ぶことになります。
#
# 高インフレの主な原因としては、以下のようなものが考えられます。
#
# (1) 需要超過
# 経済の活性化に伴い、消費や投資が活発化し、総需要が供給能力を上回る状況が続く。これにより、価格上昇圧力が高まる。
#
# (2) コスト・プッシュ
# 原油価格の高騰や賃金上昇などによって、企業の生産コストが高まり、販売価格の上昇につながる。
#
# (3) 通貨価値の下落
# 通貨価値の下落により、輸入財の価格が上昇し、物価全般に波及する。
#
# (4) インフレ期待の高まり
# 経済主体がインフレ率の上昇を予想し、先行的に価格や賃金を引き上げることで、インフレ圧力が高まる。
#
# これらの要因が相互に影響し合いながら、高インフレが持続することになります。
#
# 2. 高インフレがGDPに与える影響
# 次に、高インフレが国のGDPにどのような影響を及ぼすのかについて見ていきましょう。高インフレは、経済の各主体の行動に様々な変化を及ぼすことで、最終的にGDPの減少につながります。その具体的なメカニズムは以下の通りです。
#
# (1) 消費の減少
# 高インフレにより実質所得が減少すると、消費者の購買力が低下します。また、将来のインフレ率上昇を見越して、現在の消費を抑制する傾向も見られます。その結果、個人消費が減少し、GDPの減少につながります。
#
# (2) 投資の減少
# 高インフレ下では、企業の投資意欲が減退します。金利上昇により資金調達コストが上がるほか、将来の不確実性が高まるため、設備投資や研究開発投資などが抑制されがちです。投資の減少は、GDPの低下を招きます。
#
# (3) 輸出の減少
# 高インフレにより国内価格が上昇すると、輸出財の価格競争力が低下します。その結果、輸出が減少し、GDPの押し下げ要因となります。一方で、輸入財の価格上昇により、輸入が抑制される可能性もあります。
#
# (4) 財政の悪化
# 高インフレ下では、政府の歳出が税収の伸びを上回る可能性が高くなります。物価上昇に伴い、社会保障費や公共事業費などが増加するためです。財政赤字の拡大は、GDPの減少につながります。
#
# (5) 経済主体の意思決定の歪み
# 高インフレ下では、経済主体の意思決定が歪められる傾向にあります。例えば、企業は価格変更の頻度を上げ、消費者は購買タイミングを早めるなど、経済の効率性が損なわれます。こうした歪みもGDPの減少を招きます。
#
# 以上のように、高インフレは消費、投資、輸出、財政などの経済活動に悪影響を及ぼし、結果としてGDPの減少を招くのです。
#
# 3. 実証分析による検証
# では、実際のデータを用いて、高インフレがGDPに与える影響を検証してみましょう。ここでは、いくつかの実証研究の結果を紹介します。
#
# ある研究では、1960年代から2000年代にかけての先進国と開発途上国のデータを分析しています。その結果、インフレ率が10%を超えると、GDPの伸び率が1%ポイント程度低下することが明らかになりました。特に、インフレ率が20%を超えると、GDPの減少幅が大きくなるという非線形の関係が確認されています。
#
# また別の研究では、1970年代から2000年代にかけての先進国を対象に分析を行っています。そこでは、インフレ率が10%を超えると、GDPの伸び率が2%ポイント程度低下することが示されました。さらに、インフレ率が20%を超えると、GDPの減少幅がさらに大きくなることも明らかにされています。
#
# これらの実証研究の結果から、高インフレが経済成長を阻害する傾向にあることが確認できます。特に、インフレ率が10%を超えると、GDPの伸びが大きく鈍化し、20%を超えると、経済の停滞が深刻化することがわかります。
#
# 4. 高インフレ抑制のための政策対応
# 以上のように、高インフレはGDPの減少を招く大きな要因となります。そのため、政府や中央銀行は、高インフレの抑制に向けて様々な政策対応を講じることが重要になります。
#
# まず、金融政策の面では、中央銀行による金利引き上げが有効です。金利上昇により、消費や投資の抑制、さらには物価上昇圧力の緩和につながります。ただし、金利引き上げは経済活動を冷やす側面もあるため、適切なタイミングと幅が求められます。
#
# 次に、財政政策の面では、政府支出の抑制や増税などによる財政の引き締めが考えられます。これにより、需要面での物価上昇圧力を和らげることができます。ただし、財政引き締めは経済成長を阻害する可能性があるため、慎重な対応が必要です。
#
# また、構造改革の推進も重要です。規制緩和や競争促進などによって、企業の生産性向上や価格競争力の強化を図り、コスト・プッシュ型のインフレ圧力を和らげることができます。
#
# さらに、インフレ期待の抑制にも取り組む必要があります。中央銀行の強力なコミュニケーションによって、物価安定目標の達成に向けた決意を示すことで、経済主体のインフレ期待を抑制することができます。
#
# 以上のように、金融政策、財政政策、構造改革、インフレ期待の管理など、総合的な政策対応が求められます。高インフレの抑制なくしては、GDPの持続的な成長は望めません。
#
# 5. おわりに
# 本稿では、高インフレが国のGDPに及ぼす影響について、理論的な側面と実証的な側面の両面から検討してきました。高インフレは、消費、投資、輸出、財政などの経済活動に悪影響を及ぼし、結果としてGDPの減少を招くことが明らかになりました。
#
# また、実証分析の結果からは、インフレ率が10%を超えると、GDPの伸びが大きく鈍化し、20%を超えると、経済の停滞が深刻化することが示されました。
#
# このため、政府や中央銀行は、金融政策、財政政策、構造改革、インフレ期待の管理など、総合的な政策対応によって高インフレの抑制に取り組む必要があります。高インフレの克服なくしては、持続的な経済成長は望めません。
#
# 以上、高インフレがGDPに及ぼす影響について、詳しく述べさせていただきました。
# Input tokens:  58
# Output tokens:  2568
# Total tokens:  2626
# Stop reason: end_turn

# %%
# Copyright Amazon.com, Inc. or its affiliates. All Rights Reserved.
# SPDX-License-Identifier: Apache-2.0
"""
Shows how to use the Conversation API with Anthropic Claude 3 Sonnet (on demand).
"""

import logging
import boto3


from botocore.exceptions import ClientError


logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)


def generate_conversation(bedrock_client,
                     model_id,
                     system_text,
                     input_text):
    """
    Sends a message to a model.
    Args:
        bedrock_client: The Boto3 Bedrock runtime client.
        model_id (str): The model ID to use.
        system_text (JSON) : The system prompt.
        input text : The input message.

    Returns:
        response (JSON): The conversation that the model generated.

    """

    logger.info("Generating message with model %s", model_id)

    # Message to send.
    message = {
        "role": "user",
        "content": [{"text": input_text}]
    }
    messages = [message]
    system_prompts = [{"text" : system_text}]

    # Inference parameters to use.
    temperature = 0.5
    top_k = 200

    #Base inference parameters to use.
    inference_config = {"temperature": temperature}
    # Additional inference parameters to use.
    additional_model_fields = {"top_k": top_k}

    # Send the message.
    response = bedrock_client.converse(
        modelId=model_id,
        messages=messages,
        system=system_prompts,
        inferenceConfig=inference_config,
        additionalModelRequestFields=additional_model_fields
    )

    return response



"""
Entrypoint for Anthropic Claude 3 Sonnet example.
"""

logging.basicConfig(level=logging.INFO,
                    format="%(levelname)s: %(message)s")

model_id = "anthropic.claude-3-haiku-20240307-v1:0"
system_prompt = "あなたは大量のデータにアクセスできる日本人のエコノミストです。"
prompt = "高インフレが国のGDPに与える影響について1000文字で書いてください。"

try:

    bedrock_client = boto3.client(service_name='bedrock-runtime', region_name='us-west-2')

    response = generate_conversation(
        bedrock_client, model_id, system_prompt, prompt)

    output_message = response['output']['message']

    print(f"Role: {output_message['role']}")

    for content in output_message['content']:
        print(f"Text: {content['text']}")

    token_usage = response['usage']
    print(f"Input tokens:  {token_usage['inputTokens']}")
    print(f"Output tokens:  {token_usage['outputTokens']}")
    print(f"Total tokens:  {token_usage['totalTokens']}")
    print(f"Stop reason: {response['stopReason']}")

except ClientError as err:
    message = err.response['Error']['Message']
    logger.error("A client error occurred: %s", message)
    print(f"A client error occured: {message}")

else:
    print(
        f"Finished generating text with model {model_id}.")
# Out:
# INFO:__main__:Generating message with model anthropic.claude-3-haiku-20240307-v1:0
# Role: assistant
# Text: 高インフレが国のGDPに与える影響について、1000文字でお書きします。
#
# 高インフレは、国のGDPに深刻な影響を及ぼします。まず、高インフレは消費者の購買力を低下させます。物価が上昇すれば、同じ金額で以前より少ない商品しか購入できなくなります。これにより、個人消費が減少し、GDP成長率の鈍化につながります。
#
# また、高インフレは企業の生産活動にも悪影響を及ぼします。原材料や人件費の高騰により、企業の利益率が低下します。利益が減少すれば、企業は設備投資の抑制や雇用調整を余儀なくされ、経済全体の生産性が低下します。
#
# さらに、高インフレは国際競争力の低下にもつながります。自国通貨の価値が下落すれば、輸出製品の価格が相対的に高くなり、海外市場での競争力が失われます。一方で、輸入品の価格が上昇するため、国内需要も減少します。これらの要因により、貿易収支の悪化を招き、GDPの減少につながります。
#
# 加えて、高インフレは金融政策の運営を困難にします。中央銀行は物価安定と経済成長のバランスを取る必要があるため、高インフレ下では金利引き上げによる金融引き締めが求められます。しかし、金利上昇は企業の資金調達コストを高め、設備投資の抑制を招きます。さらに、個人消費の減少にもつながるため、GDPの低迷を招きかねません。
#
# このように、高インフレは消費、投資、貿易、金融政策など、経済の様々な側面に悪影響を及ぼします。その結果、GDPの伸び悩みや経済の停滞を招くのです。
#
# したがって、政府は物価の安定化に向けた適切な政策対応が求められます。金融政策による需要管理のみならず、供給サイドの生産性向上や規制緩和など、総合的な経済政策の実施が重要となります。また、インフレ抑制と経済成長のバランスを取ることも課題です。高インフレからの脱却には長期的な取り組みが必要不可欠です。
# Input tokens:  61
# Output tokens:  716
# Total tokens:  777
# Stop reason: end_turn
# Finished generating text with model anthropic.claude-3-haiku-20240307-v1:0.

# %%
output_message['content']
# Out:
# [{'text': '高インフレが国のGDPに与える影響について、1000文字でお書きします。\n\n高インフレは、国のGDPに深刻な影響を及ぼします。まず、高インフレは消費者の購買力を低下させます。物価が上昇すれば、同じ金額で以前より少ない商品しか購入できなくなります。これにより、個人消費が減少し、GDP成長率の鈍化につながります。\n\nまた、高インフレは企業の生産活動にも悪影響を及ぼします。原材料や人件費の高騰により、企業の利益率が低下します。利益が減少すれば、企業は設備投資の抑制や雇用調整を余儀なくされ、経済全体の生産性が低下します。\n\nさらに、高インフレは国際競争力の低下にもつながります。自国通貨の価値が下落すれば、輸出製品の価格が相対的に高くなり、海外市場での競争力が失われます。一方で、輸入品の価格が上昇するため、国内需要も減少します。これらの要因により、貿易収支の悪化を招き、GDPの減少につながります。\n\n加えて、高インフレは金融政策の運営を困難にします。中央銀行は物価安定と経済成長のバランスを取る必要があるため、高インフレ下では金利引き上げによる金融引き締めが求められます。しかし、金利上昇は企業の資金調達コストを高め、設備投資の抑制を招きます。さらに、個人消費の減少にもつながるため、GDPの低迷を招きかねません。\n\nこのように、高インフレは消費、投資、貿易、金融政策など、経済の様々な側面に悪影響を及ぼします。その結果、GDPの伸び悩みや経済の停滞を招くのです。\n\nしたがって、政府は物価の安定化に向けた適切な政策対応が求められます。金融政策による需要管理のみならず、供給サイドの生産性向上や規制緩和など、総合的な経済政策の実施が重要となります。また、インフレ抑制と経済成長のバランスを取ることも課題です。高インフレからの脱却には長期的な取り組みが必要不可欠です。'}]

# %%
from pprint import pprint
pprint(response)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '2481',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 31 May 2024 00:51:31 GMT',
#                                       'x-amzn-requestid': '864b77d8-6212-4707-8600-e9d328baa31b'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '864b77d8-6212-4707-8600-e9d328baa31b',
#                       'RetryAttempts': 0},
#  'metrics': {'latencyMs': 13585},
#  'output': {'message': {'content': [{'text': '高インフレが国のGDPに与える影響について、1000文字でお書きします。\n'
#                                              '\n'
#                                              '高インフレは、国のGDPに深刻な影響を及ぼします。まず、高インフレは消費者の購買力を低下させます。物価が上昇すれば、同じ金額で以前より少ない商品しか購入できなくなります。これにより、個人消費が減少し、GDP成長率の鈍化につながります。\n'
#                                              '\n'
#                                              'また、高インフレは企業の生産活動にも悪影響を及ぼします。原材料や人件費の高騰により、企業の利益率が低下します。利益が減少すれば、企業は設備投資の抑制や雇用調整を余儀なくされ、経済全体の生産性が低下します。\n'
#                                              '\n'
#                                              'さらに、高インフレは国際競争力の低下にもつながります。自国通貨の価値が下落すれば、輸出製品の価格が相対的に高くなり、海外市場での競争力が失われます。一方で、輸入品の価格が上昇するため、国内需要も減少します。これらの要因により、貿易収支の悪化を招き、GDPの減少につながります。\n'
#                                              '\n'
#                                              '加えて、高インフレは金融政策の運営を困難にします。中央銀行は物価安定と経済成長のバランスを取る必要があるため、高インフレ下では金利引き上げによる金融引き締めが求められます。しかし、金利上昇は企業の資金調達コストを高め、設備投資の抑制を招きます。さらに、個人消費の減少にもつながるため、GDPの低迷を招きかねません。\n'
#                                              '\n'
#                                              'このように、高インフレは消費、投資、貿易、金融政策など、経済の様々な側面に悪影響を及ぼします。その結果、GDPの伸び悩みや経済の停滞を招くのです。\n'
#                                              '\n'
#                                              'したがって、政府は物価の安定化に向けた適切な政策対応が求められます。金融政策による需要管理のみならず、供給サイドの生産性向上や規制緩和など、総合的な経済政策の実施が重要となります。また、インフレ抑制と経済成長のバランスを取ることも課題です。高インフレからの脱却には長期的な取り組みが必要不可欠です。'}],
#                         'role': 'assistant'}},
#  'stopReason': 'end_turn',
#  'usage': {'inputTokens': 61, 'outputTokens': 716, 'totalTokens': 777}}

# %%
new_user_input = {
    "role": "user",
    "content": [{"text": "具体例を教えてください。"}]
}

# %%
# !pip list | grep boto3
# Out:
# boto3                                    1.34.116

# %%
# !pip install -U boto3
# Out:
# Requirement already satisfied: boto3 in /home/renya/anaconda3/lib/python3.9/site-packages (1.34.94)
# Collecting boto3
#   Downloading boto3-1.34.116-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<1.35.0,>=1.34.116 (from boto3)
#   Downloading botocore-1.34.116-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/renya/anaconda3/lib/python3.9/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/renya/anaconda3/lib/python3.9/site-packages (from boto3) (0.10.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/renya/anaconda3/lib/python3.9/site-packages (from botocore<1.35.0,>=1.34.116->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/renya/anaconda3/lib/python3.9/site-packages (from botocore<1.35.0,>=1.34.116->boto3) (1.26.18)
# Requirement already satisfied: six>=1.5 in /home/renya/anaconda3/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.116->boto3) (1.16.0)
# Downloading boto3-1.34.116-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 8.6 MB/s eta 0:00:00
# Downloading botocore-1.34.116-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 26.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: botocore, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.94
#     Uninstalling botocore-1.34.94:
#       Successfully uninstalled botocore-1.34.94
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.34.94
#     Uninstalling boto3-1.34.94:
#       Successfully uninstalled boto3-1.34.94
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.32.93 requires botocore==1.34.93, but you have botocore 1.34.116 which is incompatible.
# Successfully installed boto3-1.34.116 botocore-1.34.116

# %%
pip install "boto3>=1.34.116"

# %%
https://aws.amazon.com/jp/about-aws/whats-new/2024/05/amazon-bedrock-new-converse-api/

# %%
import boto3
import json
brt = boto3.client(service_name='bedrock-runtime', region_name='us-west-2')

body = json.dumps({
    "prompt": "\n\nHuman: explain black holes to 8th graders\n\nAssistant:",
    "max_tokens_to_sample": 300,
    "temperature": 0.1,
    "top_p": 0.9,
})

modelId = 'anthropic.claude-v2'
accept = 'application/json'
contentType = 'application/json'

response = brt.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)

response_body = json.loads(response.get('body').read())

# text
print(response_body.get('completion'))
# Out:
#  Here is a simple explanation of black holes for 8th graders:
#
# - A black hole is a region in space where gravity is so strong that nothing can escape from it, even light. This region is called the "event horizon."
#
# - Black holes form when very massive stars collapse. When the star runs out of nuclear fuel, gravity makes it collapse. The matter gets compressed into a very small space, creating a black hole.
#
# - Black holes are called "black" because they absorb all the light that hits them. They don't reflect or emit any light that we can detect. So they appear completely black.
#
# - The gravitational pull of black holes is so strong because matter has been compressed into a tiny space. All of that mass gets concentrated into a single point called the "singularity."
#
# - Not even light can escape a black hole once it crosses the event horizon. The gravity is so intense that the escape velocity is faster than the speed of light!
#
# - Black holes warp space and time around them. They bend light and time due to their strong gravity. This causes bizarre effects like time dilation.
#
# - We can detect black holes when they suck in matter from neighboring stars and gas clouds. This material heats up and emits X-rays that we can observe with telescopes.
#
# - Supermassive black holes are thought to exist at the center of most galaxies, including our own Milky Way galaxy.

# %%
pprint(response)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '1472',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 31 May 2024 00:28:56 GMT',
#                                       'x-amzn-bedrock-input-token-count': '17',
#                                       'x-amzn-bedrock-invocation-latency': '15663',
#                                       'x-amzn-bedrock-output-token-count': '300',
#                                       'x-amzn-requestid': '150ae95e-f617-478e-bb82-477e03b3b51f'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '150ae95e-f617-478e-bb82-477e03b3b51f',
#                       'RetryAttempts': 0},
#  'body': <botocore.response.StreamingBody object at 0x7b504ee0c1f0>,
#  'contentType': 'application/json'}

# %%
pprint(response_body)
# Out:
# {'completion': ' Here is a simple explanation of black holes for 8th graders:\n'
#                '\n'
#                '- A black hole is a region in space where gravity is so strong '
#                'that nothing can escape from it, even light. This region is '
#                'called the "event horizon."\n'
#                '\n'
#                '- Black holes form when very massive stars collapse. When the '
#                'star runs out of nuclear fuel, gravity makes it collapse. The '
#                'matter gets compressed into a very small space, creating a '
#                'black hole. \n'
#                '\n'
#                '- Black holes are called "black" because they absorb all the '
#                "light that hits them. They don't reflect or emit any light "
#                'that we can detect. So they appear completely black.\n'
#                '\n'
#                '- The gravitational pull of black holes is so strong because '
#                'matter has been compressed into a tiny space. All of that mass '
#                'gets concentrated into a single point called the '
#                '"singularity." \n'
#                '\n'
#                '- Not even light can escape a black hole once it crosses the '
#                'event horizon. The gravity is so intense that the escape '
#                'velocity is faster than the speed of light!\n'
#                '\n'
#                '- Black holes warp space and time around them. They bend light '
#                'and time due to their strong gravity. This causes bizarre '
#                'effects like time dilation.\n'
#                '\n'
#                '- We can detect black holes when they suck in matter from '
#                'neighboring stars and gas clouds. This material heats up and '
#                'emits X-rays that we can observe with telescopes.\n'
#                '\n'
#                '- Supermassive black holes are thought to exist at the center '
#                'of most galaxies, including our own Milky Way galaxy.',
#  'stop': None,
#  'stop_reason': 'max_tokens',
#  'type': 'completion'}
